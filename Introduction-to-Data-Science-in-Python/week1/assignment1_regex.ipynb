# %% [markdown]
# # Assignment 1
# For this assignment you are welcomed to use other regex resources such a regex "cheat sheets" you find on the web.

# %% [markdown]
# Before start working on the problems, here is a small example to help you understand how to write your own answers. In short, the solution should be written within the function body given, and the final result should be returned. Then the autograder will try to call the function and validate your returned result accordingly. Before start working on the problems, here is a small example to help you understand how to write your own answers. In short, the solution should be written within the function body given, and the final result should be returned. Then the autograder will try to call the function and validate your returned result accordingly.

# %%
def example_word_count():
    # This example question requires counting words in the example_string below.
    example_string = "Amy is 5 years old"
    
    # YOUR CODE HERE.
    # You should write your solution here, and return your result, you can comment out or delete the
    # NotImplementedError below.
    result = example_string.split(" ")
    return len(result)

    #raise NotImplementedError()

# %% [markdown]
# ## Part A
#
# Find a list of all of the names in the following string using regex.

# %%
import re
def names():
    simple_string = """Amy is 5 years old, and her sister Mary is 2 years old. 
    Ruth and Peter, their parents, have 3 kids."""

    # YOUR CODE HERE
    return re.findall('[A-Z][a-z]+', simple_string)
    
#     raise NotImplementedError()

# %%
assert len(names()) == 4, "There are four names in the simple_string"

# %% [markdown]
# ## Part B
#
# The dataset file in [assets/grades.txt](assets/grades.txt) contains a line separated list of people with their grade in
# a class. Create a regex to generate a list of just those students who received a B in the course.

# %%
import re
def grades():
    with open ("assets/grades.txt", "r") as file:
        grades = file.read()

    # YOUR CODE HERE
    return re.findall('([A-Z][a-z]+\s[A-Z][a-z]+)(?=: B)', grades)

#     raise NotImplementedError()

# %%
assert len(grades()) == 16
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-130-829aacf4d8a8> in <module>
# ----> 1 assert len(grades()) == 16
#
# <ipython-input-129-db523fe88263> in grades()
#       1 import re
#       2 def grades():
# ----> 3     with open ("assets/grades.txt", "r") as file:
#       4         grades = file.read()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'assets/grades.txt'

# %% [markdown]
# ## Part C
#
# Consider the standard web log file in [assets/logdata.txt](assets/logdata.txt). This file records the access a user makes when visiting a web page (like this one!). Each line of the log has the following items:
# * a host (e.g., '146.204.224.152')
# * a user_name (e.g., 'feest6811' **note: sometimes the user name is missing! In this case, use '-' as the value for the username.**)
# * the time a request was made (e.g., '21/Jun/2019:15:45:24 -0700')
# * the post request type (e.g., 'POST /incentivize HTTP/1.1' **note: not everything is a POST!**)
#
# Your task is to convert this into a list of dictionaries, where each dictionary looks like the following:
# ```
# example_dict = {"host":"146.204.224.152",
#                 "user_name":"feest6811",
#                 "time":"21/Jun/2019:15:45:24 -0700",
#                 "request":"POST /incentivize HTTP/1.1"}
# ```

# %%
import re
def logs():
    with open("assets/logdata.txt", "r") as file:
        logdata = file.read()
    
    # YOUR CODE HERE
    regex_host = r'\d+\.\d+\.\d+\.\d+'
    get_host = re.findall(regex_host, logdata)    # e.g., '146.204.224.152'

    # 抓使用者名稱
    regex_user_name = r'(?<=- )([a-zA-Z0-9]+|-)' # (?<=) 抓出- 後面的使用者名稱[a-zA-Z0-9]+ 或 -。    | 表示 "或"
    regex_user_name2 = r'(?<=- )(\w+|-)(?= )'  # (?<=- )( )(?= ) 前後指定符號抓取中間
    get_user_name = re.findall(regex_user_name, logdata)  # e.g.,  feest6811 或 - 

    # 抓取時間
    regex_time = r'\d{2}\/[A-Za-z]+\/\d{4}\:\d{2}\:\d{2}\:\d{2} \-\d{4}'  # e.g.,21/Jun/2019:15:49:18 -0700
    regex_time2 = r'\d+\/\w+\/\d+\:\d+\:\d+\:\d+ \-\d+'  # 不指定數字數量
    regex_time3 = r'(?<=\[)(.+)(?=\])'  # 終極偷懶絕招，抓取[ ]內的任何字元 
    get_time = re.findall(regex_time, logdata)

    # 抓取request類型
    regex_request = r'(?<=")([\w\s\/\.]+)'  # 抓出 含有字元、空格、 / 、 . 等的字串[\w\s\/\.]+ 或  單存大寫文字的單詞[A-Z]+
    regex_request2 = r'(?<=")(.+)(?=")'
    get_request = re.findall(regex_request, logdata) # e.g., 'POST /incentivize HTTP/1.1' note: not everything is a POST!


    loglist = []  # 建立空串列
    for i in range(len(get_host)):
        logdata = dict([ ["host", get_host[i]], 
                         ["user_name", get_user_name[i]],
                         ["time", get_time[i]],
                         ["request", get_request[i]]
                       ])
        loglist.append(logdata)
        
    return loglist
    

#     raise NotImplementedError()

# %%
assert len(logs()) == 979

one_item={'host': '146.204.224.152',
  'user_name': 'feest6811',
  'time': '21/Jun/2019:15:45:24 -0700',
  'request': 'POST /incentivize HTTP/1.1'}
assert one_item in logs(), "Sorry, this item should be in the log results, check your formating"
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-133-8eb2407cb5e6> in <module>
# ----> 1 assert len(logs()) == 979
#       2
#       3 one_item={'host': '146.204.224.152',
#       4   'user_name': 'feest6811',
#       5   'time': '21/Jun/2019:15:45:24 -0700',
#
# <ipython-input-8-d1597a124e60> in logs()
#       1 import re
#       2 def logs():
# ----> 3     with open("assets/logdata.txt", "r") as file:
#       4         logdata = file.read()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'assets/logdata.txt'

# %% [markdown]
# ### 執行概念
# - 將每筆資料存成dict(包含4組key-value配對)，再存入串列list
#     - 共有979筆資料
#     - 先創造空list，使用迴圈，在迴圈內以append新增每筆資料
#
#
# - 分別指定4個變數，使用正規表達式撈出資料。用findall，回傳串列
#     - 共有host、user_name、time、request等4個key
#     - 用迴圈依序取出每筆value值
#     - 使用dict([["key1","value1"],["key2","value2"],...])來建立每筆資料

# %% [markdown]
# 將資料指定為變數logdata.txt　指定為logdata

# %%
logdata = '''
146.204.224.152 - feest6811 [21/Jun/2019:15:45:24 -0700] "POST /incentivize HTTP/1.1" 302 4622
197.109.77.178 - kertzmann3129 [21/Jun/2019:15:45:25 -0700] "DELETE /virtual/solutions/target/web+services HTTP/2.0" 203 26554
156.127.178.177 - okuneva5222 [21/Jun/2019:15:45:27 -0700] "DELETE /interactive/transparent/niches/revolutionize HTTP/1.1" 416 14701
100.32.205.59 - ortiz8891 [21/Jun/2019:15:45:28 -0700] "PATCH /architectures HTTP/1.0" 204 6048
168.95.156.240 - stark2413 [21/Jun/2019:15:45:31 -0700] "GET /engage HTTP/2.0" 201 9645
71.172.239.195 - dooley1853 [21/Jun/2019:15:45:32 -0700] "PUT /cutting-edge HTTP/2.0" 406 24498
180.95.121.94 - mohr6893 [21/Jun/2019:15:45:34 -0700] "PATCH /extensible/reinvent HTTP/1.1" 201 27330
144.23.247.108 - auer7552 [21/Jun/2019:15:45:35 -0700] "POST /extensible/infrastructures/one-to-one/enterprise HTTP/1.1" 100 22921
2.179.103.97 - lind8584 [21/Jun/2019:15:45:36 -0700] "POST /grow/front-end/e-commerce/robust HTTP/2.0" 304 14641
241.114.184.133 - tromp8355 [21/Jun/2019:15:45:37 -0700] "GET /redefine/orchestrate HTTP/1.0" 204 29059
224.188.38.4 - keebler1423 [21/Jun/2019:15:45:40 -0700] "PUT /orchestrate/out-of-the-box/unleash/syndicate HTTP/1.1" 404 28211
94.11.36.112 - klein8508 [21/Jun/2019:15:45:41 -0700] "POST /enhance/solutions/bricks-and-clicks HTTP/1.1" 404 24768
126.196.238.197 - gusikowski9864 [21/Jun/2019:15:45:45 -0700] "DELETE /rich/reinvent HTTP/2.0" 405 7894
103.247.168.212 - medhurst2732 [21/Jun/2019:15:45:49 -0700] "HEAD /scale/global/leverage HTTP/1.0" 203 15844
57.86.153.68 - dubuque8645 [21/Jun/2019:15:45:50 -0700] "POST /innovative/roi/robust/systems HTTP/1.1" 406 29046
231.220.8.214 - luettgen1860 [21/Jun/2019:15:45:52 -0700] "HEAD /systems/sexy HTTP/1.1" 201 2578
219.133.7.154 - price5585 [21/Jun/2019:15:45:53 -0700] "GET /incubate/incubate HTTP/1.1" 201 12126
159.252.184.44 - fay7852 [21/Jun/2019:15:45:54 -0700] "GET /convergence HTTP/2.0" 404 23856
40.167.172.66 - kshlerin3090 [21/Jun/2019:15:45:57 -0700] "HEAD /convergence HTTP/2.0" 501 16287
167.153.239.72 - schaden8853 [21/Jun/2019:15:45:58 -0700] "DELETE /bandwidth/reintermediate/engage HTTP/2.0" 302 17774
115.214.173.248 - hauck8214 [21/Jun/2019:15:46:00 -0700] "PUT /optimize HTTP/1.1" 401 13160
21.43.188.186 - kunze2653 [21/Jun/2019:15:46:02 -0700] "DELETE /bandwidth/turn-key/users HTTP/2.0" 201 2248
'''

# %% [markdown]
# ### 程式碼練習

# %%
import re

# 抓出網域
regex_host = r'\d+\.\d+\.\d+\.\d+'
get_host = re.findall(regex_host, logdata)    # e.g., '146.204.224.152'

# 抓使用者名稱
regex_user_name = r'(?<=- )([a-zA-Z0-9]+|-)' # (?<=) 抓出- 後面的使用者名稱[a-zA-Z0-9]+ 或 -。    | 表示 "或"
regex_user_name2 = r'(?<=- )(\w+|-)(?= )'  # (?<=- )( )(?= ) 前後指定符號抓取中間
get_user_name = re.findall(regex_user_name, logdata)  # e.g.,  feest6811 或 - 

# 抓取時間
regex_time = r'\d{2}\/[A-Za-z]+\/\d{4}\:\d{2}\:\d{2}\:\d{2} \-\d{4}'  # e.g.,21/Jun/2019:15:49:18 -0700
regex_time2 = r'\d+\/\w+\/\d+\:\d+\:\d+\:\d+ \-\d+'  # 不指定數字數量
regex_time3 = r'(?<=\[)(.+)(?=\])'  # 終極偷懶絕招，抓取[ ]內的任何字元 
get_time = re.findall(regex_time, logdata)

# 抓取request類型
regex_request = r'(?<=")([\w\s\/\.]+)'  # 抓出 含有字元、空格、 / 、 . 等的字串[\w\s\/\.]+ 或  單存大寫文字的單詞[A-Z]+
regex_request2 = r'(?<=")(.+)(?=")'
get_request = re.findall(regex_request, logdata) # e.g., 'POST /incentivize HTTP/1.1' note: not everything is a POST!


loglist = []  # 建立空串列
for i in range(len(get_host)):
    logdata = dict([ ["host", get_host[i]], 
                     ["user_name", get_user_name[i]],
                     ["time", get_time[i]],
                     ["request", get_request[i]]
                   ])
    loglist.append(logdata)

return loglist


print(len(get_host))
print(len(get_user_name))
print(len(get_time))
print(len(get_request))
loglist[:10]
# Out:
# 979
# 979
# 979
# 979
# [{'host': '146.204.224.152',
#   'user_name': 'feest6811',
#   'time': '21/Jun/2019:15:45:24 -0700',
#   'request': 'POST /incentivize HTTP/1.1'},
#  {'host': '197.109.77.178',
#   'user_name': 'kertzmann3129',
#   'time': '21/Jun/2019:15:45:25 -0700',
#   'request': 'DELETE /virtual/solutions/target/web+services HTTP/2.0'},
#  {'host': '156.127.178.177',
#   'user_name': 'okuneva5222',
#   'time': '21/Jun/2019:15:45:27 -0700',
#   'request': 'DELETE /interactive/transparent/niches/revolutionize HTTP/1.1'},
#  {'host': '100.32.205.59',
#   'user_name': 'ortiz8891',
#   'time': '21/Jun/2019:15:45:28 -0700',
#   'request': 'PATCH /architectures HTTP/1.0'},
#  {'host': '168.95.156.240',
#   'user_name': 'stark2413',
#   'time': '21/Jun/2019:15:45:31 -0700',
#   'request': 'GET /engage HTTP/2.0'},
#  {'host': '71.172.239.195',
#   'user_name': 'dooley1853',
#   'time': '21/Jun/2019:15:45:32 -0700',
#   'request': 'PUT /cutting-edge HTTP/2.0'},
# ...

# %% [markdown]
# #### finditer # 回傳可迭代物件

# %%
import re

regex_user_name2 = r'(?<=- )(\w+|-)(?= )' 
name_finditer = re.finditer(regex_user_name2, logdata)


for  match in name_finditer: # i 本身也是可迭代物件，所以下面要使用 i.group()
    # Start index of match (integer)
    sStart = match.start()

    # Final index of match (integer)
    sEnd = match.end()

    # Complete match (string)
    sGroup = match.group()

    # Print match
    print('Match "{}" found at: [{},{}]'.format(sGroup, sStart,sEnd))
# Out:
# Match "feest6811" found at: [19,28]
# Match "kertzmann3129" found at: [113,126]
# Match "okuneva5222" found at: [241,252]
# Match "ortiz8891" found at: [372,381]
# Match "stark2413" found at: [469,478]
# Match "dooley1853" found at: [557,567]
# Match "mohr6893" found at: [652,660]
# Match "auer7552" found at: [755,763]
# Match "lind8584" found at: [884,892]
# Match "tromp8355" found at: [1000,1009]
# Match "keebler1423" found at: [1101,1112]
# Match "klein8508" found at: [1228,1237]
# Match "gusikowski9864" found at: [1348,1362]
# Match "medhurst2732" found at: [1452,1464]
# Match "dubuque8645" found at: [1558,1569]
# Match "luettgen1860" found at: [1672,1684]
# Match "price5585" found at: [1769,1778]
# Match "fay7852" found at: [1869,1876]
# Match "kshlerin3090" found at: [1960,1972]
# Match "schaden8853" found at: [2058,2069]
# Match "hauck8214" found at: [2178,2187]
# Match "kunze2653" found at: [2268,2277]

# %%
regex_time = r'\d{2}\/[A-Za-z]+\/\d{4}\:\d{2}\:\d{2}\:\d{2} \-\d{4}'  # e.g.,21/Jun/2019:15:49:18 -0700
regex_time2 = r'\d+\/\w+\/\d+\:\d+\:\d+\:\d+ \-\d+'  # 不指定數字數量
regex_time3 = r'(?<=\[)(.+)(?=\])'  # 終極偷懶絕招，抓取[ ]內的任何字元 
get_time = re.findall(regex_time, logdata)

# %% [markdown]
# ### regex example ： group()使用

# %%
import re
source = '''I wish I may, I wish I might
Have a dish of fish tonight.'''

re.findall('(?<=I )[a-z]+', source) # 抓出 'I '後面的小寫單字
# Out:
# ['wish', 'may', 'wish', 'might']

# %%
# 使用search  僅回傳一筆資料，但可包含多個群組
m = re.search(r'(?P<DISH>. dish).*(?P<FISH>fish)', source)  

print(m)                   # 檢視回傳之物件 span=(34, 48), match='a dish of fish'> 
print(m.groups())          # 叫出所有群組內match物件
print(m.group('DISH'))     # 用名字呼叫
print(m.group(1))          # 用群組順序呼叫 1
print(m.group(2))          # 用群組順序呼叫 2
# Out:
# <re.Match object; span=(34, 48), match='a dish of fish'>
# ('a dish', 'fish')
# a dish
# a dish
# fish

# %% [markdown]
# ### 答案長度驗證

# %%
solution_length=[[15, 9, 26, 26],
 [14, 13, 26, 54],
 [15, 11, 26, 61],
 [13, 9, 26, 29],
 [14, 9, 26, 20],
 [14, 10, 26, 26],
 [13, 8, 26, 35],
 [14, 8, 26, 63],
 [12, 8, 26, 47],
 [15, 9, 26, 34],
 [12, 11, 26, 58],
 [12, 9, 26, 50],
 [15, 14, 26, 30],
 [15, 12, 26, 36],
 [12, 11, 26, 44],
 [13, 12, 26, 27],
 [13, 9, 26, 31],
 [14, 7, 26, 25],
 [13, 12, 26, 26],
 [14, 11, 26, 48],
 [15, 9, 26, 22],
 [13, 9, 26, 41],
 [13, 11, 26, 32],
 [12, 11, 26, 43],
 [14, 11, 26, 47],
 [11, 7, 26, 37],
 [14, 1, 26, 25],
 [13, 10, 26, 34],
 [15, 1, 26, 48],
 [14, 10, 26, 45],
 [14, 1, 26, 31],
 [12, 9, 26, 25],
 [14, 8, 26, 66],
 [15, 1, 26, 42],
 [13, 1, 26, 42],
 [14, 1, 26, 29],
 [10, 1, 26, 31],
 [12, 11, 26, 34],
 [15, 1, 26, 55],
 [12, 11, 26, 52],
 [11, 1, 26, 24],
 [15, 1, 26, 50],
 [14, 11, 26, 31],
 [13, 11, 26, 41],
 [14, 9, 26, 59],
 [13, 1, 26, 48],
 [14, 11, 26, 52],
 [14, 1, 26, 25],
 [14, 10, 26, 48],
 [14, 9, 26, 26],
 [14, 1, 26, 55],
 [12, 11, 26, 56],
 [13, 1, 26, 44],
 [15, 1, 26, 50],
 [13, 10, 26, 44],
 [13, 1, 26, 57],
 [15, 1, 26, 26],
 [14, 1, 26, 58],
 [14, 1, 26, 21],
 [12, 9, 26, 39],
 [14, 1, 26, 45],
 [13, 12, 26, 23],
 [13, 1, 26, 33],
 [12, 1, 26, 55],
 [15, 1, 26, 33],
 [13, 1, 26, 59],
 [11, 1, 26, 38],
 [15, 1, 26, 35],
 [13, 1, 26, 41],
 [12, 12, 26, 25],
 [14, 1, 26, 51],
 [13, 1, 26, 61],
 [12, 1, 26, 41],
 [15, 9, 26, 26],
 [14, 11, 26, 58],
 [13, 11, 26, 21],
 [14, 8, 26, 62],
 [14, 1, 26, 43],
 [15, 1, 26, 31],
 [12, 10, 26, 24],
 [12, 1, 26, 33],
 [13, 12, 26, 55],
 [15, 13, 26, 25],
 [13, 1, 26, 33],
 [12, 1, 26, 23],
 [14, 13, 26, 39],
 [11, 15, 26, 46],
 [12, 1, 26, 52],
 [14, 1, 26, 47],
 [14, 12, 26, 35],
 [14, 1, 26, 50],
 [14, 12, 26, 51],
 [11, 1, 26, 31],
 [14, 1, 26, 23],
 [13, 10, 26, 22],
 [13, 1, 26, 52],
 [13, 14, 26, 30],
 [14, 12, 26, 27],
 [15, 1, 26, 43],
 [14, 9, 26, 47],
 [14, 11, 26, 58],
 [14, 9, 26, 53],
 [13, 1, 26, 38],
 [15, 1, 26, 44],
 [15, 8, 26, 25],
 [13, 1, 26, 24],
 [13, 1, 26, 31],
 [14, 11, 26, 56],
 [14, 12, 26, 36],
 [15, 11, 26, 28],
 [14, 1, 26, 40],
 [13, 1, 26, 50],
 [15, 10, 26, 39],
 [13, 13, 26, 27],
 [14, 10, 26, 32],
 [14, 9, 26, 51],
 [14, 10, 26, 54],
 [12, 1, 26, 32],
 [14, 1, 26, 53],
 [12, 11, 26, 38],
 [12, 9, 26, 57],
 [14, 10, 26, 36],
 [13, 11, 26, 34],
 [14, 1, 26, 34],
 [13, 1, 26, 45],
 [13, 1, 26, 62],
 [14, 1, 26, 29],
 [10, 1, 26, 46],
 [13, 10, 26, 19],
 [12, 10, 26, 26],
 [12, 10, 26, 35]]

# %%
your_length = [[len(d[k]) for k in ["host", "user_name", "time", "request"]] for d in loglist]

assert len(solution_length)==len(your_length), "your list does not have the correct number of entries"

for j in range(len(solution_length)):
    if solution_length[j]!=your_length[j]:
        print("Index number    : {}".format(j))
        print("Solution length : {}".format(solution_length[j]))
        print("Your length     : {}".format(your_length[j]))

# %%
# Out:
# {'host': '34.188.163.50',
#  'user_name': '-',
#  'time': '21/Jun/2019:15:46:57 -0700',
#  'request': 'PATCH /interactive/architect/innovative/24%2f7 HTTP/1.1'}
